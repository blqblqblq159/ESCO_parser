# %%
import pandas as pd
import numpy as np
import random
from py2neo import Graph
from sklearn.manifold import TSNE
import seaborn as sns

# %%
df = pd.read_csv('New_LinkedIn_users.csv')
df.head()
# Out:
#    Unnamed: 0                memberUrn  ageEstimate        companyName  \
# 0           0   urn:li:member:10013136           41  Commonwealth Bank
# 1           1   urn:li:member:10013136           41            CommSec
# 2           2   urn:li:member:10013136           41  Commonwealth Bank
# 3           3   urn:li:member:10013136           41  Commonwealth Bank
# 4           4  urn:li:member:100186032           30    Jigsaw Clothing
#
#    companyStaffCount                    companyUrl  \
# 0            32905.0   http://www.commbank.com.au/
# 1              619.0     http://www.commsec.com.au
# 2            32905.0   http://www.commbank.com.au/
# 3            32905.0   http://www.commbank.com.au/
# 4              447.0  http://www.jigsaw-online.com
#
#                                    mbrTitle   startDate     endDate  \
# 0  Portfolio Executive at Commonwealth Bank  2007-01-02  01/07/2008
# 1  Portfolio Executive at Commonwealth Bank  2008-01-08  01/12/2012
# 2  Portfolio Executive at Commonwealth Bank  2013-01-11  01/06/2014
# 3  Portfolio Executive at Commonwealth Bank  2014-01-07         NaN
# 4          Senior Marketing Manager, PayPal  2009-01-01  01/12/2009
#
#         ESCO_job_title  predictionConfidence
# 0  executive assistant                  86.0
# 1  executive assistant                  86.0
# 2  executive assistant                  86.0
# 3  executive assistant                  86.0
# 4    marketing manager                  90.0

# %%
print(df[df['memberUrn']=='urn:li:member:10013136']['ESCO_job_title'].apply(pd.Series).stack().tolist())
# Out:
# ['executive assistant', 'executive assistant', 'executive assistant', 'executive assistant']

# %%
unique_urns = list(set(df['memberUrn'].apply(pd.Series).stack().tolist()))
print(len(unique_urns))
# Out:
# 6853

# %%
urn_jobhist = []
for urn in unique_urns:
    jobhist = df[df['memberUrn']==urn]['ESCO_job_title'].apply(pd.Series).stack().tolist()
    urn_jobhist.append([urn,jobhist])
urn_jobhist_df = pd.DataFrame(urn_jobhist,columns = ["urn", "ESCO_job_history"])

# %%
urn_jobhist_df.head()
# Out:
#                        urn                                   ESCO_job_history
# 0   urn:li:member:63253473  [hospitality revenue manager, hospitality reve...
# 1   urn:li:member:47270882  [shoe and leather accessories shop manager, sh...
# 2  urn:li:member:122496914  [food safety specialist, food safety specialis...
# 3   urn:li:member:34349914  [religious education teacher at secondary scho...
# 4  urn:li:member:162583050  [librarian, librarian, librarian, librarian, l...

# %%
job_skills_df = pd.read_csv('title_uri_skills.csv')
job_skills_df.head()
# Out:
#                         job_title  \
# 0                     3D animator
# 1                     3D modeller
# 2          3D printing technician
# 3      abrasive blasting operator
# 4  absorbent pad machine operator
#
#                                                  uri  \
# 0  http://data.europa.eu/esco/occupation/52df9d56...
# 1  http://data.europa.eu/esco/occupation/bab5fa79...
# 2  http://data.europa.eu/esco/occupation/4cf7be91...
# 3  http://data.europa.eu/esco/occupation/3c0af499...
# 4  http://data.europa.eu/esco/occupation/c706886d...
#
#                                     essential_skills  \
# 0  ['3D texturing', 'create 3D environments', 'pa...
# 1  ['use polygonal modelling', 'develop creative ...
# 2  ['use technical drawing software', 'create sol...
# 3  ['wear appropriate protective gear', 'remove i...
# 4  ['adhesives', 'supply machine', 'troubleshoot'...
#
#                                      optional_skills
# 0  ['manage schedule of tasks', 'create animated ...
# 1  ['C++', 'Smalltalk (computer programming)', 'c...
# 2  ['CADD software', 'manual draughting technique...
# 3  ['set up the controller of a machine', 'monito...
# 4  ['monitor paper reel', 'operate compression ro...

# %%
def assign_skills(df_in):
    df = df_in.copy()
    essential_percentage = 0.5
    optional_percentage = 0.2
    skills_list = []
    for line in df.iterrows():
        skills = set()
        essential_percentage_per_occupation = essential_percentage# / len(line[1]['ESCO_job_history'])
        optional_percentage_per_occupation = optional_percentage# / len(line[1]['ESCO_job_history'])
        for job in line[1]['ESCO_job_history']:
            #the try-except block are necessary, since some occupations do not have any associated skills, these would throw an error otherwise
            try:
                for e_skill in job_skills_df[job_skills_df['job_title']==job]['essential_skills'].item().replace('[','').replace(']','').replace("'",'').split(','):
                    if np.random.uniform() < essential_percentage_per_occupation:
                        skills.add(e_skill.strip())
            except:
                pass
            try:
                for o_skill in job_skills_df[job_skills_df['job_title']==job]['optional_skills'].item().replace('[','').replace(']','').replace("'",'').split(','):
                    if np.random.uniform() < optional_percentage_per_occupation:
                        skills.add(o_skill.strip())
            except:
                pass
        skills_list.append(list(skills))
    df['skills'] = skills_list
    return df

# %%
df_with_skills = assign_skills(urn_jobhist_df)
df_with_skills.head()
# Out:
#                        urn                                   ESCO_job_history  \
# 0   urn:li:member:63253473  [hospitality revenue manager, hospitality reve...
# 1   urn:li:member:47270882  [shoe and leather accessories shop manager, sh...
# 2  urn:li:member:122496914  [food safety specialist, food safety specialis...
# 3   urn:li:member:34349914  [religious education teacher at secondary scho...
# 4  urn:li:member:162583050  [librarian, librarian, librarian, librarian, l...
#
#                                               skills
# 0  [forecast occupancy demand, analyse booking pa...
# 1  [ensure correct goods labelling, set sales goa...
# 2  [develop food safety programmes, ensure correc...
# 3                                                 []
# 4  [assist in library facility planning, confer w...

# %% [markdown]
# There are a couple of way to assign jobs to these people. A first one that I will explore is to make a graph embedding of the people (urns) and the occupations based on the skills they have/require. We use node2vec to create the ebedding.
#
# To do this, we first have to enter these people in the database and do some more preprocessing. We again create weighted edges between people or people and jobs depending on the skills they share.

# %%
#first, remove all the people that did not get assigned any skills
for i,line in enumerate(df_with_skills.iterrows()):
    if not line[1]['skills']:
        df_with_skills['skills'][i] = np.nan
df_with_skills_cleaned = df_with_skills.dropna()
df_with_skills_cleaned.head()
# Out:
#                        urn                                   ESCO_job_history  \
# 0   urn:li:member:63253473  [hospitality revenue manager, hospitality reve...
# 1   urn:li:member:47270882  [shoe and leather accessories shop manager, sh...
# 2  urn:li:member:122496914  [food safety specialist, food safety specialis...
# 4  urn:li:member:162583050  [librarian, librarian, librarian, librarian, l...
# 5  urn:li:member:258253757  [dismantling engineer, dismantling engineer, d...
#
#                                               skills
# 0  [forecast occupancy demand, analyse booking pa...
# 1  [ensure correct goods labelling, set sales goa...
# 2  [develop food safety programmes, ensure correc...
# 4  [assist in library facility planning, confer w...
# 5  [identify construction materials from blueprin...

# %%
expanded_list = []
for i, row in df_with_skills_cleaned.iterrows():
    urn = row['urn']
    for skill in row['skills']:
        if skill:
            expanded_list.append([urn, skill])
expanded_df = pd.DataFrame(expanded_list, columns=['urn','skill'])
expanded_df.to_csv('expanded_df_with_skills.csv',index=False)
expanded_df.head()
# Out:
#                       urn                      skill
# 0  urn:li:member:63253473  forecast occupancy demand
# 1  urn:li:member:63253473   analyse booking patterns
# 2  urn:li:member:63253473               inspect data
# 3  urn:li:member:63253473            train employees
# 4  urn:li:member:63253473   conduct financial audits

# %%
expanded_list = []
for i, row in df_with_skills_cleaned.iterrows():
    urn = row['urn']
    for job in row['ESCO_job_history']:
        if job:
            expanded_list.append([urn, job])
expanded_df = pd.DataFrame(expanded_list, columns=['urn','job'])
expanded_df.to_csv('expanded_df_with_jobhist.csv',index=False)
expanded_df.head()
# Out:
#                       urn                                        job
# 0  urn:li:member:63253473                hospitality revenue manager
# 1  urn:li:member:63253473                hospitality revenue manager
# 2  urn:li:member:63253473                hospitality revenue manager
# 3  urn:li:member:63253473                hospitality revenue manager
# 4  urn:li:member:47270882  shoe and leather accessories shop manager

# %%
len(df_with_skills_cleaned)
# Out:
# 6224

# %%
with open('credentials.txt','r') as f:
    ls = f.read().split(', ')

DN_HOST = 'localhost'
DB_PORT = 7687
DB_USERNAME = ls[0]
DB_PW = ls[1]
DB_NAME = 'neo4j'

graph = Graph(
    host=DN_HOST,
    port=DB_PORT,
    user=DB_USERNAME,
    password=DB_PW,
    name=DB_NAME
)

# %%
graph.run("""
    CALL gds.beta.node2vec.write({
    nodeQuery:'MATCH (n) WHERE n:Person or n:Occupation RETURN id(n) AS id',
    relationshipQuery:'MATCH (n)-[a]->(:skill)<-[b]-(m)
        RETURN id(n) AS source, id(m) AS target, sum(a.weight*b.weight) AS weight',
    validateRelationships:false,
    writeProperty:'embedding',
    relationshipWeightProperty:'weight'})
""")
# Out:
#  nodeCount | nodePropertiesWritten | createMillis | computeMillis | writeMillis | configuration
# -----------|-----------------------|--------------|---------------|-------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#       9138 |                  9138 |      1017305 |         62725 |         363 | {negativeSamplingExponent: 0.75, initialLearningRate: 0.025, writeConcurrency: 4, negativeSamplingRate: 5, walksPerNode: 10, positiveSamplingFactor: 0.001, relationshipWeightProperty: 'weight', iterations: 1, concurrency: 4, returnFactor: 1.0, walkLength: 80, windowSize: 10, writeProperty: 'embedding', inOutFactor: 1.0, embeddingDimension: 128, nodeLabels: ['*'], sudo: false, minLearningRate: 0.0001, relationshipTypes: ['*'], walkBufferSize: 1000, username: null}

# %%
embed_df = graph.run("""
    MATCH (n) WHERE n:Person or n:Occupation RETURN n.embedding AS node_embedding, labels(n) AS label, n as nodes
""").to_data_frame()
node_embed_2d = TSNE().fit_transform(np.array([x for x in embed_df['node_embedding']]))
sns.scatterplot(x=[x[0] for x in node_embed_2d],y=[x[1] for x in node_embed_2d],hue = [x[0] for x in embed_df['label']])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# <AxesSubplot:>

# %%
embed_df = graph.run("""
    MATCH (n) WHERE n:Person or n:Occupation RETURN n.embedding AS node_embedding, labels(n)[0] AS label, n.urn as urn, n.title as title
""").to_data_frame()
np_embed = []
for embed in embed_df['node_embedding']:
    np_embed.append(np.array(embed))
embed_df['np_node_embedding'] = np_embed
occupation_df = embed_df.dropna(subset=['title']).reset_index()[['np_node_embedding','label','title']]
person_df = embed_df.dropna(subset=['urn']).reset_index()[['np_node_embedding','label','urn']]
person_df.head()
# Out:
#                                    np_node_embedding   label  \
# 0  [-0.18186289072036743, -0.31261634826660156, -...  Person
# 1  [-0.005847466178238392, -0.4316405951976776, -...  Person
# 2  [0.19794590771198273, -0.846646785736084, -0.0...  Person
# 3  [0.021608319133520126, -0.5021878480911255, 0....  Person
# 4  [0.11355864256620407, -0.2245677262544632, -0....  Person
#
#                        urn
# 0   urn:li:member:63253473
# 1   urn:li:member:47270882
# 2  urn:li:member:122496914
# 3  urn:li:member:162583050
# 4  urn:li:member:258253757

# %%
def get_top_k_occupations(embedding,k):
    distances = []
    for i,embed in enumerate(occupation_df['np_node_embedding']):
        distance = np.linalg.norm(embedding-embed)
        distances.append(distance)
    distances = np.array(distances)
    idx = np.argsort(distances)
    top_k_distances = distances[idx[:k]]
    top_k_occupations = occupation_df['title'][idx[:k]]
    transposed = []
    for a,b in zip(top_k_occupations,top_k_distances):
        transposed.append([a,b])
    return pd.DataFrame(transposed,columns = ['occupation','distance'])

def get_top_k_people(embedding,k):
    distances = []
    for i,embed in enumerate(person_df['np_node_embedding']):
        distance = np.linalg.norm(embedding-embed)
        distances.append(distance)
    distances = np.array(distances)
    idx = np.argsort(distances)
    top_k_distances = distances[idx[:k]]
    top_k_people = person_df['urn'][idx[:k]]
    transposed = []
    for a,b in zip(top_k_people,top_k_distances):
        transposed.append([a,b])
    return pd.DataFrame(transposed,columns = ['urn','distance'])

def get_person_history(urn):
    return df_with_skills_cleaned[df_with_skills_cleaned['urn']==urn]['ESCO_job_history'].item()

def get_person_skills(urn):
    return df_with_skills_cleaned[df_with_skills_cleaned['urn']==urn]['skills'].item()

# %%
#given a person, find its most applicable occupations
urn_list = df_with_skills_cleaned['urn'].tolist()
rand_urn = random.sample(urn_list,1)[0]
k=10
print(f'We find the best suited jobs for person with urn {rand_urn}.')
print('Their job history consist of:')
for job in get_person_history(rand_urn):
    print(f'\t{job}')
print('')
print('Their skills are:')
for skill in get_person_skills(rand_urn):
    print(f'\t{skill}')
print('')
print(f'Top {k} recommended jobs are:')
occ_df = get_top_k_occupations(person_df[person_df['urn']==rand_urn]['np_node_embedding'].item(),k)
occ_df
# Out:
# We find the best suited job for person with urn urn:li:member:198432439.
# Their job history consist of:
# 	consul
# 	consul
# 	consul
# 	consul
# 	consul
# 	consul
# 	consul
# 	consul
# 	consul
#
# Their skills are:
# 	commercial law
# 	government policy implementation
# 	diplomatic principles
# 	respond to enquiries
# 	facilitate official agreement
# 	apply immigration law
# 	organise cultural events
# 	ensure cross-department cooperation
# 	international commercial transactions rules
# 	analyse problems for opportunities
# 	offer assistance to national citizens
# 	economics
# 	speak different languages
# 	public finance
# 	maintain relationships with government agencies
# 	manage government policy implementation
# 	look after trade delegations
# 	assess risk factors
# 	show intercultural awareness
# 	advise on public finance
# 	foreign affairs
# 	international law
# 	issue official documents
# 	family law
# 	coordinate government activities in foreign institutions
# 	build international relations
# 	consider economic criteria in decision making
# 	government representation
# 	perform political negotiation
# 	advise on foreign affairs policies
# 	develop international cooperation strategies
# 	develop professional network
# 	apply diplomatic principles
#
# Top 10 recommended jobs are:
#                         occupation  distance
# 0  international relations officer  1.865780
# 1        political affairs officer  1.962946
# 2                         diplomat  1.980466
# 3               embassy counsellor  1.987156
# 4                           consul  2.065718
# 5    social security administrator  2.098036
# 6                        ombudsman  2.111609
# 7         labour relations officer  2.112999
# 8                       ambassador  2.124782
# 9              immigration adviser  2.144921

# %%
#given a job find the most applicable people
job_list = job_skills_df['job_title'].tolist()
rand_job = random.sample(job_list,1)[0]
k=5
print(f'We find the best suited people for job {rand_job}.')
print(f'Top {k} recommended people are:')
per_df = get_top_k_people(occupation_df[occupation_df['title']==rand_job]['np_node_embedding'].item(),k)
per_df
# Out:
# We find the best suited people for job engine designer.
# Top 5 recommended people are:
#                        urn  distance
# 0  urn:li:member:322285203  2.377058
# 1  urn:li:member:235120453  2.377753
# 2   urn:li:member:43553394  2.389261
# 3  urn:li:member:145841156  2.429627
# 4  urn:li:member:433126915  2.431211

# %%
#who are these people?
print('for these people, we check out their job history and skills.')
for i,person in enumerate(per_df['urn']):
    print(f'person {person}:')
    print('job history:')
    for job in get_person_history(person):
        print(f'\t{job}')
    print('')
    print('skills:')
    for skill in get_person_skills(person):
        print(f'\t{skill}')
    print('')
    print('')
# Out:
# for these people, we check out their job history and skills.
# person urn:li:member:322285203:
# job history:
# 	electrical engineer
# 	electrical engineer
# 	electrical engineer
# 	electrical engineer
# 	electrical engineer
# 	electrical engineer
#
# skills:
# 	consumer electronics
# 	"identify customers needs"
# 	electrical wiring plans
# 	power engineering
# 	mechatronics
# 	electrical wiring diagrams
# 	design circuit boards
# 	mathematics
# 	design drawings
# 	install hardware
# 	hardware materials
# 	environmental threats
# 	control systems
# 	define quality standards
# 	install operating system
# 	R
# 	ML (computer programming)
# 	electrical engineering
# 	risk management
# 	firmware
# 	Smalltalk (computer programming)
# 	develop electronic test procedures
# 	C++
# 	Scala
# 	prepare assembly drawings
# 	CAM software
# 	perform data analysis
# 	Erlang
# 	OpenEdge Advanced Business Language
# 	write routine reports
# 	perform project management
# 	Groovy
# 	mechanics
# 	electronics
# 	solder electronics
# 	hardware platforms
# 	SAP R3
# 	electromagnetic spectrum
# 	SAS language
# 	PHP
# 	design electric power systems
# 	electricity principles
# 	microelectronics
# 	VBScript
# 	Objective-C
# 	electric generators
# 	use CAE software
# 	ASP.NET
# 	test microelectromechanical systems
# 	robotic components
# 	AJAX
# 	build business relationships
# 	operate precision machinery
# 	assess supplier risks
# 	physics
# 	microassembly
# 	Java (computer programming)
# 	program firmware
# 	ensure material compliance
# 	maintain safe engineering watches
# 	electrical machines
# 	COBOL
# 	process customer orders
# 	read engineering drawings
# 	electromagnetism
# 	apply health and safety standards
# 	monitor machine operations
# 	use CAD software
# 	engineering principles
# 	gather technical information
# 	examine engineering principles
# 	manufacturing processes
# 	design firmware
# 	assemble instrumentation equipment
# 	microwave principles
# 	assemble electromechanical systems
# 	coordinate engineering teams
# 	Pascal (computer programming)
# 	electronic test procedures
# 	materials science
# 	Scratch (computer programming)
# 	maintain electrical engines
# 	microelectromechanical systems
# 	analyse test data
# 	perform test run
# 	develop test procedures
# 	environmental legislation
# 	operate scientific measuring equipment
# 	automotive engineering
# 	monitor manufacturing quality standards
# 	Visual Studio .NET
# 	design microelectronics
# 	instrumentation engineering
# 	electricity
# 	draft bill of materials
# 	MOEM
# 	Prolog (computer programming)
# 	create software design
# 	create technical plans
# 	assemble microelectromechanical systems
# 	integrated circuits
# 	design sensors
# 	Assembly (computer programming)
# 	model sensor
# 	align software with system architectures
# 	electrical testing methods
# 	CAE software
# 	develop instrumentation systems
# 	design control systems
# 	design integrated circuits
# 	abide by regulations on banned materials
# 	power electronics
# 	test hardware
# 	Python (computer programming)
# 	apply soldering techniques
# 	electric motors
# 	design prototypes
# 	conduct quality control analysis
# 	acoustics
# 	transmission technology
# 	adjust engineering designs
# 	electromechanics
# 	process customer requests based on the REACh Regulation 1907 2006
# 	building automation
# 	Swift (computer programming)
# 	printed circuit boards
# 	perform scientific research
# 	prepare production prototypes
# 	design hardware
# 	digital camera sensors
# 	Common Lisp
# 	design microelectromechanical systems
# 	CAD software
# 	hardware testing methods
# 	product data management
# 	design electronic systems
# 	JavaScript
# 	biomedical engineering
# 	perform resource planning
# 	automation technology
# 	electric drives
# 	TypeScript
# 	Perl
# 	nanoelectronics
# 	design principles
# 	Lisp
# 	control engineering
# 	approve engineering design
# 	install software
# 	types of electronics
# 	execute feasibility study
# 	precision mechanics
# 	APL
# 	radars
# 	optics
# 	troubleshoot
# 	design electromagnets
# 	hardware architectures
# 	use technical drawing software
#
#
# person urn:li:member:235120453:
# job history:
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
#
# skills:
# 	ensure compliance with safety legislation
# 	mechanics of vessels
# 	train employees
# 	blueprints
# 	use tools for construction and repair
# 	power engineering
# 	wear appropriate protective gear
# 	supervise electricity distribution operations
# 	mechanical engineering
# 	irrigation systems
# 	mathematics
# 	mechatronics
# 	report analysis results
# 	simulate mechatronic design concepts
# 	manage the operation of propulsion plant machinery
# 	ensure safety in electrical power operations
# 	thermodynamics
# 	air conditioning and refrigeration parts
# 	microprocessors
# 	design ventilation network
# 	conduct performance tests
# 	follow safety standards in industrial contexts
# 	monitor electric generators
# 	electrical engineering
# 	domestic heating systems
# 	follow company standards
# 	quality standards
# 	survive at sea in the event of ship abandonment
# 	manage ship emergency plans
# 	maintain electronic equipment
# 	"create a products virtual model"
# 	install heating
# 	types of containers
# 	prepare assembly drawings
# 	perform data analysis
# 	write routine reports
# 	perform project management
# 	operate marine machinery systems
# 	mechanics
# 	medical device test procedures
# 	principles of mechanical engineering
# 	solder electronics
# 	use a computer
# 	quality and cycle time optimisation
# 	monitor production developments
# 	evaluate engine performance
# 	operation of different engines
# 	operate control systems
# 	design electric power systems
# 	use thermal management
# 	electricity principles
# 	biomedical techniques
# 	communicate with customers
# 	electric generators
# 	components of air conditioning systems
# 	risks associated with undertaking fishing operations
# 	perform small vessel safety procedures
# 	ventilation
# 	design thermal requirements
# 	oversee quality control
# 	electrical power safety regulations
# 	cybernetics
# 	assess financial viability
# 	keep up with digital transformation of industrial processes
# 	engineering processes
# 	robotic components
# 	inspect underground power cables
# 	define manufacturing quality criteria
# 	install transport equipment engines
# 	build business relationships
# 	extinguish fires
# 	apply advanced manufacturing
# 	operate precision machinery
# 	pollution legislation
# 	physics
# 	stealth technology
# 	create solutions to problems
# 	provide advice to technicians
# 	work in outdoor conditions
# 	radiation physics in healthcare
# 	manage supplies
# 	program firmware
# 	research improvement of crop yields
# 	install heating boiler
# 	determine production feasibility
# 	read engineering drawings
# 	fisheries legislation
# 	read standard blueprints
# 	calibrate mechatronic instruments
# 	Global Maritime Distress and Safety System
# 	diagnostic radiology
# 	install circuit breakers
# 	robotics
# 	project management
# 	engineering principles
# 	optoelectronics
# 	examine engineering principles
# 	gather technical information
# 	biology
# 	electricity consumption
# 	manufacturing processes
# 	re-assemble engines
# 	quality of fish products
# 	oversee construction project
# 	design firmware
# 	define technical requirements
# 	pneumatics
# 	analyse test data
# 	international regulations for preventing collisions at sea
# 	microelectromechanical systems
# 	use precision tools
# 	radiation protection
# 	ICT software specifications
# 	monitor manufacturing quality standards
# 	inspect engine rooms
# 	repair medical devices
# 	lubricate engines
# 	perform small vessel safety measures
# 	draft bill of materials
# 	provide cost benefit analysis reports
# 	mechanics of motor vehicles
# 	manufacture medical devices
# 	create software design
# 	maintain electrical equipment
# 	heat transfer processes
# 	operate life-saving appliances
# 	apply medical first aid on board ship
# 	assess environmental impact
# 	prevent fires on board
# 	ensure compliance with environmental legislation
# 	inspect overhead power lines
# 	technical drawings
# 	CAE software
# 	operate electronic measuring instruments
# 	operate pumping systems
# 	design medical devices
# 	analyse production processes for improvement
# 	engine components
# 	communicate using the global maritime distress and safety system
# 	develop software prototype
# 	conduct literature research
# 	plan manufacturing processes
# 	fisheries management
# 	electricity market
# 	3D modelling
# 	transmission towers
# 	ensure compliance with electricity distribution schedule
# 	fire-fighting systems
# 	agricultural production principles
# 	conduct quality control analysis
# 	ventilation systems
# 	adjust engineering designs
# 	electromechanics
# 	make electrical calculations
# 	biotechnology
# 	civil engineering
# 	industrial engineering
# 	Prevent sea pollution
# 	perform scientific research
# 	use computer-aided engineering systems
# 	advise on irrigation projects
# 	develop agricultural policies
# 	adjust voltage
# 	manage engineering project
# 	mechanics of trains
# 	respond to electrical power contingencies
# 	install mechatronic equipment
# 	CAD software
# 	design automation components
# 	production processes
# 	bicycle mechanics
# 	product data management
# 	develop medical device test procedures
# 	biomedical engineering
# 	report test findings
# 	hydraulics
# 	perform resource planning
# 	automation technology
# 	design thermal equipment
# 	assessment of risks and threats
# 	set up automotive robot
# 	develop strategies for electricity contingencies
# 	use thermal analysis
# 	design principles
# 	aerodynamics
# 	control engineering
# 	approve engineering design
# 	precision mechanics
# 	model medical devices
# 	execute feasibility study
# 	maintain agricultural machinery
# 	coordinate fire fighting
# 	troubleshoot
# 	interpret 3D plans
# 	technical terminology
# 	test procedures in electricity transmission
# 	create AutoCAD drawings
# 	industrial heating systems
# 	safety engineering
# 	use technical drawing software
# 	ensure equipment cooling
#
#
# person urn:li:member:43553394:
# job history:
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
#
# skills:
# 	train employees
# 	blueprints
# 	supervise electricity distribution operations
# 	wear appropriate protective gear
# 	fluid mechanics
# 	provide advice to farmers
# 	irrigation systems
# 	install automation components
# 	mathematics
# 	mechanical engineering
# 	power engineering
# 	report analysis results
# 	manage the operation of propulsion plant machinery
# 	ensure safety in electrical power operations
# 	thermodynamics
# 	air conditioning and refrigeration parts
# 	test medical devices
# 	repair engines
# 	monitor electric generators
# 	electrical engineering
# 	wear cleanroom suit
# 	domestic heating systems
# 	firmware
# 	develop electronic test procedures
# 	survive at sea in the event of ship abandonment
# 	manage ship emergency plans
# 	maintain electronic equipment
# 	"create a products virtual model"
# 	install heating
# 	lead a team in fishery services
# 	types of containers
# 	refrigerants
# 	disassemble engines
# 	computer engineering
# 	operate marine machinery systems
# 	mechanics
# 	electronics
# 	swim
# 	principles of mechanical engineering
# 	aircraft mechanics
# 	solder electronics
# 	use a computer
# 	monitor production developments
# 	replace machines
# 	conduct training on biomedical equipment
# 	evaluate engine performance
# 	install heating furnace
# 	pollution prevention
# 	operate control systems
# 	design electric power systems
# 	set up the controller of a machine
# 	use thermal management
# 	electricity principles
# 	biomedical techniques
# 	communicate with customers
# 	risks associated with undertaking fishing operations
# 	ventilation
# 	design thermal requirements
# 	electrical discharge
# 	electrical power safety regulations
# 	assess financial viability
# 	keep up with digital transformation of industrial processes
# 	engineering processes
# 	test mechatronic units
# 	robotic components
# 	install transport equipment engines
# 	define manufacturing quality criteria
# 	build business relationships
# 	apply advanced manufacturing
# 	maintain control systems for automated equipment
# 	physics
# 	stealth technology
# 	create solutions to problems
# 	use CAM software
# 	use testing equipment
# 	provide training
# 	manage supplies
# 	determine production capacity
# 	liaise with engineers
# 	program firmware
# 	maintain safe engineering watches
# 	install heating boiler
# 	determine production feasibility
# 	read standard blueprints
# 	reverse engineering
# 	apply technical communication skills
# 	calibrate mechatronic instruments
# 	Global Maritime Distress and Safety System
# 	install circuit breakers
# 	use CAD software
# 	robotics
# 	engineering principles
# 	optoelectronics
# 	examine engineering principles
# 	electricity consumption
# 	manufacturing processes
# 	define technical requirements
# 	manage engine-room resources
# 	pneumatics
# 	international regulations for preventing collisions at sea
# 	perform test run
# 	use precision tools
# 	assemble robots
# 	environmental legislation
# 	thermal materials
# 	monitor manufacturing quality standards
# 	provide technical documentation
# 	perform small vessel safety measures
# 	provide cost benefit analysis reports
# 	manufacture medical devices
# 	maintain electrical equipment
# 	heat transfer processes
# 	create technical plans
# 	monitor automated machines
# 	apply medical first aid on board ship
# 	operate life-saving appliances
# 	ensure vessel compliance with regulations
# 	draft design specifications
# 	prevent fires on board
# 	assess environmental impact
# 	inspect overhead power lines
# 	technical drawings
# 	operate pumping systems
# 	operate electronic measuring instruments
# 	design medical devices
# 	analyse production processes for improvement
# 	engine components
# 	manage workflow processes
# 	use technical documentation
# 	International Convention for the Prevention of Pollution from Ships
# 	plan manufacturing processes
# 	electricity market
# 	ensure compliance with electricity distribution schedule
# 	"manipulate medical devices materials"
# 	fire-fighting systems
# 	medical device regulations
# 	operate ship propulsion system
# 	material mechanics
# 	design prototypes
# 	conduct quality control analysis
# 	telecommunications engineering
# 	develop mechatronic test procedures
# 	adjust engineering designs
# 	electromechanics
# 	use maritime English
# 	biotechnology
# 	civil engineering
# 	Prevent sea pollution
# 	perform scientific research
# 	interpret technical requirements
# 	prepare production prototypes
# 	use computer-aided engineering systems
# 	advise on irrigation projects
# 	manage engineering project
# 	navigation and control
# 	install mechatronic equipment
# 	CAD software
# 	product data management
# 	biomedical engineering
# 	hydraulics
# 	micromechatronic engineering
# 	perform resource planning
# 	synthetic natural environment
# 	set up automotive robot
# 	heating
# 	medical imaging technology
# 	control engineering
# 	approve engineering design
# 	precision mechanics
# 	model medical devices
# 	electric current
# 	maintain agricultural machinery
# 	coordinate fire fighting
# 	interpret 3D plans
# 	test procedures in electricity transmission
# 	industrial heating systems
# 	record test data
# 	use technical drawing software
#
#
# person urn:li:member:145841156:
# job history:
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
# 	mechanical engineer
#
# skills:
# 	ensure compliance with safety legislation
# 	mechanics of vessels
# 	maintain shipboard machinery
# 	ship related legislative requirements
# 	train employees
# 	blueprints
# 	use tools for construction and repair
# 	power engineering
# 	supervise electricity distribution operations
# 	wear appropriate protective gear
# 	mechanical engineering
# 	provide advice to farmers
# 	irrigation systems
# 	mechatronics
# 	install automation components
# 	fluid mechanics
# 	report analysis results
# 	simulate mechatronic design concepts
# 	design drawings
# 	manage the operation of propulsion plant machinery
# 	ensure safety in electrical power operations
# 	thermodynamics
# 	air conditioning and refrigeration parts
# 	microprocessors
# 	test medical devices
# 	maintain robotic equipment
# 	design ventilation network
# 	follow safety standards in industrial contexts
# 	repair engines
# 	monitor electric generators
# 	wear cleanroom suit
# 	electrical engineering
# 	domestic heating systems
# 	firmware
# 	follow company standards
# 	develop electronic test procedures
# 	develop product design
# 	survive at sea in the event of ship abandonment
# 	quality standards
# 	manage ship emergency plans
# 	"create a products virtual model"
# 	install heating
# 	types of containers
# 	prepare assembly drawings
# 	lead a team in fishery services
# 	perform data analysis
# 	refrigerants
# 	disassemble engines
# 	computer engineering
# 	work in a fishery team
# 	write routine reports
# 	perform project management
# 	operate marine machinery systems
# 	mechanics
# 	electronics
# 	medical device test procedures
# 	swim
# 	principles of mechanical engineering
# 	aircraft mechanics
# 	analyse stress resistance of products
# 	design engineering components
# 	solder electronics
# 	use a computer
# 	quality and cycle time optimisation
# 	monitor production developments
# 	conduct training on biomedical equipment
# 	evaluate engine performance
# 	install heating furnace
# 	operate control systems
# 	operation of different engines
# 	design electric power systems
# 	electricity principles
# 	medical devices materials
# 	biomedical techniques
# 	communicate with customers
# 	components of air conditioning systems
# 	execute analytical mathematical calculations
# 	risks associated with undertaking fishing operations
# 	perform small vessel safety procedures
# 	design thermal requirements
# 	ventilation
# 	oversee quality control
# 	electrical power safety regulations
# 	cybernetics
# 	assess financial viability
# 	interpret 2D plans
# 	engineering processes
# 	test mechatronic units
# 	inspect underground power cables
# 	define manufacturing quality criteria
# 	install transport equipment engines
# 	build business relationships
# 	extinguish fires
# 	apply advanced manufacturing
# 	maintain control systems for automated equipment
# 	operate precision machinery
# 	multimedia systems
# 	pollution legislation
# 	physics
# 	stealth technology
# 	create solutions to problems
# 	use testing equipment
# 	provide advice to technicians
# 	provide training
# 	radiation physics in healthcare
# 	manage supplies
# 	determine production capacity
# 	liaise with engineers
# 	advise on pollution prevention
# 	scientific research methodology
# 	program firmware
# 	maintain safe engineering watches
# 	research improvement of crop yields
# 	install heating boiler
# 	read engineering drawings
# 	determine production feasibility
# 	fisheries legislation
# 	reverse engineering
# 	read standard blueprints
# 	apply technical communication skills
# 	calibrate mechatronic instruments
# 	Global Maritime Distress and Safety System
# 	diagnostic radiology
# 	install circuit breakers
# 	project management
# 	engineering principles
# 	debug software
# 	optoelectronics
# 	examine engineering principles
# 	gather technical information
# 	electricity consumption
# 	re-assemble engines
# 	design firmware
# 	quality of fish products
# 	oversee construction project
# 	manufacturing processes
# 	analytical methods in biomedical sciences
# 	define technical requirements
# 	manage engine-room resources
# 	coordinate engineering teams
# 	medical devices
# 	health informatics
# 	pneumatics
# 	analyse test data
# 	international regulations for preventing collisions at sea
# 	perform test run
# 	microelectromechanical systems
# 	use precision tools
# 	radiation protection
# 	operate scientific measuring equipment
# 	ICT software specifications
# 	operate ship rescue machinery
# 	monitor manufacturing quality standards
# 	inspect engine rooms
# 	provide technical documentation
# 	repair medical devices
# 	lubricate engines
# 	mechanics of motor vehicles
# 	provide cost benefit analysis reports
# 	manufacture medical devices
# 	maintain electrical equipment
# 	create technical plans
# 	operate life-saving appliances
# 	apply medical first aid on board ship
# 	draft design specifications
# 	prevent fires on board
# 	assess environmental impact
# 	inspect overhead power lines
# 	technical drawings
# 	biomedical science
# 	CAE software
# 	operate electronic measuring instruments
# 	operate pumping systems
# 	control production
# 	design medical devices
# 	analyse production processes for improvement
# 	engine components
# 	communicate using the global maritime distress and safety system
# 	develop software prototype
# 	conduct literature research
# 	International Convention for the Prevention of Pollution from Ships
# 	fisheries management
# 	electricity market
# 	3D modelling
# 	ensure compliance with electricity distribution schedule
# 	transmission towers
# 	fire-fighting systems
# 	plan manufacturing processes
# 	fishing vessels
# 	"manipulate medical devices materials"
# 	agricultural production principles
# 	operate ship propulsion system
# 	material mechanics
# 	design prototypes
# 	ventilation systems
# 	telecommunications engineering
# 	develop mechatronic test procedures
# 	adjust engineering designs
# 	electromechanics
# 	use maritime English
# 	make electrical calculations
# 	biotechnology
# 	develop electricity distribution schedule
# 	Prevent sea pollution
# 	perform scientific research
# 	interpret technical requirements
# 	inspect facility sites
# 	use computer-aided engineering systems
# 	develop agricultural policies
# 	manage electricity transmission system
# 	adjust voltage
# 	advise on irrigation projects
# 	prepare production prototypes
# 	respond to electrical power contingencies
# 	mechanics of trains
# 	navigation and control
# 	install mechatronic equipment
# 	CAD software
# 	product data management
# 	design automation components
# 	develop medical device test procedures
# 	report test findings
# 	hydraulics
# 	micromechatronic engineering
# 	perform resource planning
# 	human anatomy
# 	design thermal equipment
# 	synthetic natural environment
# 	set up automotive robot
# 	aerodynamics
# 	use thermal analysis
# 	design principles
# 	assessment of risks and threats
# 	medical imaging technology
# 	develop strategies for electricity contingencies
# 	control engineering
# 	approve engineering design
# 	precision mechanics
# 	execute feasibility study
# 	electric current
# 	coordinate fire fighting
# 	maintain agricultural machinery
# 	troubleshoot
# 	interpret 3D plans
# 	technical terminology
# 	test procedures in electricity transmission
# 	industrial heating systems
# 	safety engineering
# 	use technical drawing software
# 	ensure equipment cooling
#
#
# person urn:li:member:433126915:
# job history:
# 	chemical engineer
# 	chemical engineer
# 	chemical engineer
#
# skills:
# 	ensure compliance with safety legislation
# 	test chemical samples
# 	engineering principles
# 	evaluate pharmaceutical manufacturing process
# 	examine engineering principles
# 	manage chemical testing procedures
# 	biology
# 	manufacturing processes
# 	supply chain management
# 	adjust engineering designs
# 	drug administration regulations
# 	materials science
# 	develop chemical products
# 	analyse test data
# 	perform scientific research
# 	toxicology
# 	pharmaceutical technology
# 	thermoplastic materials
# 	work with chemicals
# 	engineering processes
# 	provide technical expertise
# 	design optical systems
# 	define quality standards
# 	quality assurance methodologies
# 	electrical engineering
# 	apply validation engineering
# 	monitor plant production
# 	pollution legislation
# 	manage pharmaceutical production facilities construction
# 	test production input materials
# 	quality standards
# 	industrial software
# 	physics
# 	create solutions to problems
# 	design principles
# 	perform chemical experiments
# 	draft design specifications
# 	analytical chemistry
# 	approve engineering design
# 	forecast organisational risks
# 	assess environmental impact
# 	write batch record documentation
# 	computer engineering
# 	write technical reports
# 	chemistry
# 	design pharmaceutical manufacturing systems
# 	mechanics
# 	basic chemicals
# 	pharmacology
# 	semiconductors
# 	record test data
# 	improve chemical processes
# 	apply health and safety standards
# 	types of metal
# 	packaging engineering
# 	use a computer
